# %% [markdown]
# <a href="https://colab.research.google.com/github/LeeM21/python/blob/master/1%EC%9D%BC%EC%B0%A8_1%EC%B0%A8%EC%8B%9C_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('인천정보산업고')
# Out:
# 인천정보산업고

# %%
a=1
b=2
a
b
print(a,b)
# Out:
# 1 2

# %%
a=3
b=2
print('a+b=',a+b)
print('a-b=',a-b)
print('a*b=',a*b)
print('a**b=',a**b)
print('a/b=',a/b)
print('a//b=',a//b)
print('a%b=',a%b)
# Out:
# a+b= 5
# a-b= 1
# a*b= 6
# a**b= 9
# a/b= 1.5
# a//b= 1
# a%b= 1

# %% [markdown]
# 오늘은**1일차 1교시 출력문**작성내용입니다.
# --
# 오늘의 학습목표
# 1. 개발환경 설치
# 2. 출력문 작성
#
# **정리**
# 1. 파이썬은 ;이 필요없다.
# 2. print()라는 함수를 이용해서 출력을 한다.
# 3. 문자열은  " "가 아닌 ' '로 표현한다.
