# %% [markdown]
# ## 공공데이터

# %%
import pandas as pd

# %%
path = r'C:\Users\user\Desktop\302\covid_v.csv'
df=pd.read_csv(path,encoding='cp949')

# %%
df
# Out:
#     no          구분 작물정보                                              효능·효과  \
# 0    1        염증제거   마늘  ○ 항산화 성분이 풍부해서 면역력을 높여주고 항암작용을 함 - 몸속의 독소를 배출하...
# 1    2  호흡기계 감염 예방  도라지  ○ 도라지의 사포닌은 기침, 가래, 염증을 완화시켜주고, 기관지 및 호흡기 건강에 ...
# 2    3  호흡기계 감염 예방  도라지  ○ 도라지의 사포닌은 기침, 가래, 염증을 완화시켜주고, 기관지 및 호흡기 건강에 ...
# 3    4     면역력 증진    삼채  ○ 국산 삼채는 수입산보다 필수 아미노산, 식이 황 및 사포닌의 함량이 많음. - ...
# 4    5     면역력 증진    달래  ○ 면역력을 높여주는 비타민 A, 신경계를 안정시키며 스트레스를 풀어주는 비타민 B...
# 5    6     면역력 증진    두릅  ○ 비타민 A, B, C의 함량이 많아서 원기 회복, 면역체계 강화에 도움 - 강심...
# 6    7     면역력 증진   미나리  ○ 자연살해세포의 활성을 높여 면역력 강화 효과를 보임 - 칼륨이 많이 함유되어 있...
# 7    8        감기치료  산마늘  ○ 무기질과 비타민 함량이 많고, 이뇨, 해독, 동맥경화 및 소화 개선 효과 - 비...
# 8    9        혈액순환   냉이  ○ 아르기닌, 프롤린, 메티오닌 등 아미노산이 풍부하며, 특히 프롤린은 스트레스 해...
# 9   10     면역력 증진   토마토  ○ 면역세포의 증식 및 항체 생산의 증가를 통해 면역력 증진 - 토마토에는 라이코펜...
# 10  11     면역력 증진    생강  ○ 면역세포의 증식과 복강 대식세포에 의한 사이토카인 분비능력을 상승시켜 면역 기관...
#
#                                               요리조리복용법
# 0   ○ 마늘 부르스케타 - 재료 : 햇마늘 2통, 바게트 빵 3조각, 올리브유 2T, ...
# 1   ○ 도라지 맛탕 - 재료 : 도라지 7개, 식용유 2컵, 찹쌀가루 1/2컵, 소금 ...
# 2   ○ 도라지탕 불고기  - 재료 : 도라지 3개, 볶음용 소고기 180g, 당근 1/...
# 3   ○ 삼채 김치찌개 - 재료 : 삼채 뿌리 30g, 배추김치 1/2포기, 돼지고기 1...
# 4   ○ 돼지고기 달래 샐러드 - 재료 : 달래 32g, 봄동 5장, 돼지고기 볶음용 1...
# 5   ○ 두릅 냉국 - 재료 : 두릅 6개, 국물용 멸치 10마리, 다시마 1장 - 양념...
# 6   ○ 미나리 덮밥 - 재료 : 차돌박이 280g, 미나리 80g, 현미밥 2공기, 양...
# 7   ○ 산마늘 주먹밥 - 재료 : 산마늘 잎 20장, 불고기 600g, 밥 2공기, 참...
# 8   ○ 냉이무침 - 재료 : 냉이 200g, 통깨 1/2T - 양념장 : 고추장 2T,...
# 9   ○ 토마토밥브리토 - 재료 : 양파 ¼개, 햄 60g, 통조림 옥수수 2T, 쌀밥 ...
# 10  ○ 생강초절임 - 재료 : 생강 500g, 비트 30g (1.2ℓ 분량)절임물 재료...

# %%
df.head()
# Out:
#    no          구분 작물정보                                              효능·효과  \
# 0   1        염증제거   마늘  ○ 항산화 성분이 풍부해서 면역력을 높여주고 항암작용을 함 - 몸속의 독소를 배출하...
# 1   2  호흡기계 감염 예방  도라지  ○ 도라지의 사포닌은 기침, 가래, 염증을 완화시켜주고, 기관지 및 호흡기 건강에 ...
# 2   3  호흡기계 감염 예방  도라지  ○ 도라지의 사포닌은 기침, 가래, 염증을 완화시켜주고, 기관지 및 호흡기 건강에 ...
# 3   4     면역력 증진    삼채  ○ 국산 삼채는 수입산보다 필수 아미노산, 식이 황 및 사포닌의 함량이 많음. - ...
# 4   5     면역력 증진    달래  ○ 면역력을 높여주는 비타민 A, 신경계를 안정시키며 스트레스를 풀어주는 비타민 B...
#
#                                              요리조리복용법
# 0  ○ 마늘 부르스케타 - 재료 : 햇마늘 2통, 바게트 빵 3조각, 올리브유 2T, ...
# 1  ○ 도라지 맛탕 - 재료 : 도라지 7개, 식용유 2컵, 찹쌀가루 1/2컵, 소금 ...
# 2  ○ 도라지탕 불고기  - 재료 : 도라지 3개, 볶음용 소고기 180g, 당근 1/...
# 3  ○ 삼채 김치찌개 - 재료 : 삼채 뿌리 30g, 배추김치 1/2포기, 돼지고기 1...
# 4  ○ 돼지고기 달래 샐러드 - 재료 : 달래 32g, 봄동 5장, 돼지고기 볶음용 1...

# %%
df.tail()
# Out:
#     no       구분 작물정보                                              효능·효과  \
# 6    7  면역력 증진   미나리  ○ 자연살해세포의 활성을 높여 면역력 강화 효과를 보임 - 칼륨이 많이 함유되어 있...
# 7    8     감기치료  산마늘  ○ 무기질과 비타민 함량이 많고, 이뇨, 해독, 동맥경화 및 소화 개선 효과 - 비...
# 8    9     혈액순환   냉이  ○ 아르기닌, 프롤린, 메티오닌 등 아미노산이 풍부하며, 특히 프롤린은 스트레스 해...
# 9   10  면역력 증진   토마토  ○ 면역세포의 증식 및 항체 생산의 증가를 통해 면역력 증진 - 토마토에는 라이코펜...
# 10  11  면역력 증진    생강  ○ 면역세포의 증식과 복강 대식세포에 의한 사이토카인 분비능력을 상승시켜 면역 기관...
#
#                                               요리조리복용법
# 6   ○ 미나리 덮밥 - 재료 : 차돌박이 280g, 미나리 80g, 현미밥 2공기, 양...
# 7   ○ 산마늘 주먹밥 - 재료 : 산마늘 잎 20장, 불고기 600g, 밥 2공기, 참...
# 8   ○ 냉이무침 - 재료 : 냉이 200g, 통깨 1/2T - 양념장 : 고추장 2T,...
# 9   ○ 토마토밥브리토 - 재료 : 양파 ¼개, 햄 60g, 통조림 옥수수 2T, 쌀밥 ...
# 10  ○ 생강초절임 - 재료 : 생강 500g, 비트 30g (1.2ℓ 분량)절임물 재료...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 5 columns):
# no         11 non-null int64
# 구분         11 non-null object
# 작물정보       11 non-null object
# 효능·효과      11 non-null object
# 요리조리복용법    11 non-null object
# dtypes: int64(1), object(4)
# memory usage: 568.0+ bytes

# %%
df.shape
# Out:
# (11, 5)

# %%
df.columns
# Out:
# Index(['no', '구분', '작물정보', '효능·효과', '요리조리복용법'], dtype='object')

# %%
df.isnull()
# Out:
#        no     구분   작물정보  효능·효과  요리조리복용법
# 0   False  False  False  False    False
# 1   False  False  False  False    False
# 2   False  False  False  False    False
# 3   False  False  False  False    False
# 4   False  False  False  False    False
# 5   False  False  False  False    False
# 6   False  False  False  False    False
# 7   False  False  False  False    False
# 8   False  False  False  False    False
# 9   False  False  False  False    False
# 10  False  False  False  False    False

# %%
import sys
sys.version_info
# Out:
# sys.version_info(major=3, minor=7, micro=4, releaselevel='final', serial=0)

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
path = r'C:\Users\user\Downloads\21.csv'
df = pd.read_csv(path,encoding='cp949')
df.head()
# Out:
#    일련번호      기준일자       국가자산물건관리번호                             국가자산물건명  \
# 0     1  20160822  2011-022216-505  전라남도 장성군 동화면 남산리 432-6, 433, 453-2
# 1     2  20160822  2016-072991-850               경기도 이천시 백사면 현방리 212-1
# 2     3  20160822  2013-030641-577              경상남도 양산시 상북면 소석리 553-3
# 3     4  20160822  2014-052078-451                  인천광역시 남구 주안동 589-5
# 4     5  20160822  2012-053072-922               경기도 포천시 이동면 연곡리 826-8
#
#    매각자산공매번호  국가자산물건상태코드 국가자산물건상태코드명  매각자산처분방법코드 매각자산처분방법코드명  공매유찰횟수  ...  \
# 0   9251756           3          취소           2      임대(대부)      12  ...
# 1   9251756           3          취소           2      임대(대부)       5  ...
# 2   9251756           3          취소           2      임대(대부)       0  ...
# 3   9251756           5          유찰           2      임대(대부)      20  ...
# 4   9251756           3          취소           2      임대(대부)       0  ...
#
#    유가증권표준산업분류명  유가증권종목명  유가증권지분율 유가증권지분주식수 유가증권발행회사대표자성명 매각자산회원권명 매각자산회원권번호내용  \
# 0          NaN      NaN      NaN       NaN           NaN      NaN         NaN
# 1          NaN      NaN      NaN       NaN           NaN      NaN         NaN
# 2          NaN      NaN      NaN       NaN           NaN      NaN         NaN
# 3          NaN      NaN      NaN       NaN           NaN      NaN         NaN
# 4          NaN      NaN      NaN       NaN           NaN      NaN         NaN
#
#   매각자산평형내용  회원권계좌수  대금납부방법내용
# 0      NaN     NaN       NaN
# 1      NaN     NaN       NaN
# 2      NaN     NaN       NaN
# 3      NaN     NaN       NaN
# 4      NaN     NaN       NaN
#
# [5 rows x 62 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48240 entries, 0 to 48239
# Data columns (total 62 columns):
# 일련번호              48240 non-null int64
# 기준일자              48240 non-null int64
# 국가자산물건관리번호        48240 non-null object
# 국가자산물건명           48240 non-null object
# 매각자산공매번호          48240 non-null int64
# 국가자산물건상태코드        48240 non-null int64
# 국가자산물건상태코드명       48240 non-null object
# 매각자산처분방법코드        48240 non-null int64
# 매각자산처분방법코드명       48240 non-null object
# 공매유찰횟수            48240 non-null int64
# 매각자산위임기관코드        0 non-null float64
# 매각자산위임기관명         0 non-null float64
# 매각자산집행기관번호        48240 non-null int64
# 매각자산집행기관명         48240 non-null object
# 매각자산기관지점명         48240 non-null object
# 매각자산기관담당자성명       48240 non-null object
# 매각자산기관담당자전화번호     48240 non-null object
# 매각자산기관담당자이메일주소    471 non-null object
# 감정평가평균금액          48240 non-null int64
# 최저공매가             48240 non-null int64
# 최저입찰가내용           48240 non-null object
# 매각공고일자            48240 non-null int64
# 국가자산대분류코드         48240 non-null int64
# 국가자산대분류코드명        48240 non-null object
# 국가자산중분류코드         48240 non-null int64
# 국가자산중분류코드명        48240 non-null object
# 국가자산소분류코드         48240 non-null int64
# 국가자산소분류코드명        48240 non-null object
# 국가자산소재지구우편번호      5371 non-null float64
# 국가자산소재지지번주소       48240 non-null object
# 국가자산소재지시도명        46315 non-null object
# 국가자산소재지시군구명       46323 non-null object
# 국가자산소재지상세주소       46315 non-null object
# 국가자산소재지도로명주소      48237 non-null object
# 국가자산소재지도로명상세주소    4550 non-null object
# 국가자산소재지도로명        5373 non-null object
# 국가자산명도책임내용        48240 non-null object
# 국가자산처분조건내용        48240 non-null object
# 국가자산배분요구최종일자      0 non-null float64
# 국가자산건물면적값         46463 non-null float64
# 국가자산토지면적값         46463 non-null float64
# 국가자산실태조사일자        48237 non-null float64
# 국가자산위치부근현황내용      46463 non-null object
# 국가자산이용현황내용        46430 non-null object
# 국가자산상세내용          47796 non-null object
# 물건증권법인명           0 non-null float64
# 기타물품명             0 non-null float64
# 서화작가성명            0 non-null float64
# 서화규격내용            0 non-null float64
# 동산크기내용            0 non-null float64
# 차량번호내용            1777 non-null object
# 유가증권종류명           0 non-null float64
# 유가증권표준산업분류명       1777 non-null object
# 유가증권종목명           1777 non-null object
# 유가증권지분율           1777 non-null float64
# 유가증권지분주식수         1777 non-null float64
# 유가증권발행회사대표자성명     1777 non-null object
# 매각자산회원권명          0 non-null float64
# 매각자산회원권번호내용       0 non-null float64
# 매각자산평형내용          0 non-null float64
# 회원권계좌수            0 non-null float64
# 대금납부방법내용          0 non-null float64
# dtypes: float64(20), int64(13), object(29)
# memory usage: 22.8+ MB

# %%
df.shape
# Out:
# (48240, 62)

# %%
df.sample()
# Out:
#         일련번호      기준일자       국가자산물건관리번호                  국가자산물건명  매각자산공매번호  \
# 14072  14073  20180730  2014-071484-519  경기도 용인시 처인구 모현읍 갈담리 611   9362547
#
#        국가자산물건상태코드 국가자산물건상태코드명  매각자산처분방법코드 매각자산처분방법코드명  공매유찰횟수  ...  \
# 14072           3          취소           2      임대(대부)       0  ...
#
#        유가증권표준산업분류명  유가증권종목명  유가증권지분율 유가증권지분주식수 유가증권발행회사대표자성명 매각자산회원권명  \
# 14072          NaN      NaN      NaN       NaN           NaN      NaN
#
#       매각자산회원권번호내용 매각자산평형내용  회원권계좌수  대금납부방법내용
# 14072         NaN      NaN     NaN       NaN
#
# [1 rows x 62 columns]

# %%
df.columns
# Out:
# Index(['일련번호', '기준일자', '국가자산물건관리번호', '국가자산물건명', '매각자산공매번호', '국가자산물건상태코드',
#        '국가자산물건상태코드명', '매각자산처분방법코드', '매각자산처분방법코드명', '공매유찰횟수', '매각자산위임기관코드',
#        '매각자산위임기관명', '매각자산집행기관번호', '매각자산집행기관명', '매각자산기관지점명', '매각자산기관담당자성명',
#        '매각자산기관담당자전화번호', '매각자산기관담당자이메일주소', '감정평가평균금액', '최저공매가', '최저입찰가내용',
#        '매각공고일자', '국가자산대분류코드', '국가자산대분류코드명', '국가자산중분류코드', '국가자산중분류코드명',
#        '국가자산소분류코드', '국가자산소분류코드명', '국가자산소재지구우편번호', '국가자산소재지지번주소', '국가자산소재지시도명',
#        '국가자산소재지시군구명', '국가자산소재지상세주소', '국가자산소재지도로명주소', '국가자산소재지도로명상세주소',
#        '국가자산소재지도로명', '국가자산명도책임내용', '국가자산처분조건내용', '국가자산배분요구최종일자', '국가자산건물면적값',
#        '국가자산토지면적값', '국가자산실태조사일자', '국가자산위치부근현황내용', '국가자산이용현황내용', '국가자산상세내용',
#        '물건증권법인명', '기타물품명', '서화작가성명', '서화규격내용', '동산크기내용', '차량번호내용', '유가증권종류명',
#        '유가증권표준산업분류명', '유가증권종목명', '유가증권지분율', '유가증권지분주식수', '유가증권발행회사대표자성명',
#        '매각자산회원권명', '매각자산회원권번호내용', '매각자산평형내용', '회원권계좌수', '대금납부방법내용'],
#       dtype='object')

# %%
df.dtypes
# Out:
# 일련번호             int64
# 기준일자             int64
# 국가자산물건관리번호      object
# 국가자산물건명         object
# 매각자산공매번호         int64
#                 ...
# 매각자산회원권명       float64
# 매각자산회원권번호내용    float64
# 매각자산평형내용       float64
# 회원권계좌수         float64
# 대금납부방법내용       float64
# Length: 62, dtype: object

# %%
df.isnull()
# Out:
#         일련번호   기준일자  국가자산물건관리번호  국가자산물건명  매각자산공매번호  국가자산물건상태코드  국가자산물건상태코드명  \
# 0      False  False       False    False     False       False        False
# 1      False  False       False    False     False       False        False
# 2      False  False       False    False     False       False        False
# 3      False  False       False    False     False       False        False
# 4      False  False       False    False     False       False        False
# ...      ...    ...         ...      ...       ...         ...          ...
# 48235  False  False       False    False     False       False        False
# 48236  False  False       False    False     False       False        False
# 48237  False  False       False    False     False       False        False
# 48238  False  False       False    False     False       False        False
# 48239  False  False       False    False     False       False        False
#
#        매각자산처분방법코드  매각자산처분방법코드명  공매유찰횟수  ...  유가증권표준산업분류명  유가증권종목명  유가증권지분율  \
# 0           False        False   False  ...         True     True     True
# 1           False        False   False  ...         True     True     True
# 2           False        False   False  ...         True     True     True
# 3           False        False   False  ...         True     True     True
# 4           False        False   False  ...         True     True     True
# ...           ...          ...     ...  ...          ...      ...      ...
# 48235       False        False   False  ...        False    False    False
# 48236       False        False   False  ...        False    False    False
# 48237       False        False   False  ...        False    False    False
# 48238       False        False   False  ...        False    False    False
# 48239       False        False   False  ...        False    False    False
#
#        유가증권지분주식수  유가증권발행회사대표자성명  매각자산회원권명  매각자산회원권번호내용  매각자산평형내용  회원권계좌수  \
# 0           True           True      True         True      True    True
# 1           True           True      True         True      True    True
# 2           True           True      True         True      True    True
# 3           True           True      True         True      True    True
# 4           True           True      True         True      True    True
# ...          ...            ...       ...          ...       ...     ...
# 48235      False          False      True         True      True    True
# 48236      False          False      True         True      True    True
# 48237      False          False      True         True      True    True
# 48238      False          False      True         True      True    True
# 48239      False          False      True         True      True    True
#
#        대금납부방법내용
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# ...         ...
# 48235      True
# 48236      True
# 48237      True
# 48238      True
# 48239      True
#
# [48240 rows x 62 columns]

# %%
null_count=df.isnull().sum()
df_null = null_count.reset_index()
df_null
# Out:
#           index      0
# 0          일련번호      0
# 1          기준일자      0
# 2    국가자산물건관리번호      0
# 3       국가자산물건명      0
# 4      매각자산공매번호      0
# ..          ...    ...
# 57     매각자산회원권명  48240
# 58  매각자산회원권번호내용  48240
# 59     매각자산평형내용  48240
# 60       회원권계좌수  48240
# 61     대금납부방법내용  48240
#
# [62 rows x 2 columns]

# %%
df_null.columns = ['메뉴','결측']
df_null
# Out:
#              메뉴     결측
# 0          일련번호      0
# 1          기준일자      0
# 2    국가자산물건관리번호      0
# 3       국가자산물건명      0
# 4      매각자산공매번호      0
# ..          ...    ...
# 57     매각자산회원권명  48240
# 58  매각자산회원권번호내용  48240
# 59     매각자산평형내용  48240
# 60       회원권계좌수  48240
# 61     대금납부방법내용  48240
#
# [62 rows x 2 columns]
